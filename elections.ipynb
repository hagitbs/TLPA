# %%
import pandas as pd
import altair as alt
import numpy as np
from pathlib import Path
from helpers import read

import bottleneck as bn
# import re
# from algo import KLD_distance_overused
# import string
# from glob import glob
# from collections import Counter
# from datetime import datetime
from xLPA import Corpus, sockpuppet_distance
from math import floor
from scipy.spatial.distance import cdist

from visualize import sockpuppet_matrix
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %%
bn.nanmean([1,2,4])
# Out:
# 2.3333333333333335

# %%
df = pd.read_csv("data/us_elections/1976-2020-president.csv")[["year", "candidatevotes", "party_simplified", "state"]]
df = df[df["party_simplified"].isin(["DEMOCRAT", "REPUBLICAN"])].rename(columns={"state": "element", "year": "document", "candidatevotes": "frequency_in_document"}).reset_index(drop=True)
# cs = []
# for party in ["DEMOCRAT", "DEMOCRAT"]:
#     corpus = Corpus(df[df["party_simplified"] == party].reset_index(drop=True))
#     dvr = corpus.create_dvr()
#     sigs = corpus.create_signatures(epsilon=1/(len(dvr) * 2))
#     cs.append(corpus)
# spd = sockpuppet_distance(*cs)
# sockpuppet_matrix(spd, "DEMOCRAT", "DEMOCRAT 1") #.save("dem_vs_dem.html")

# %%
corpus = Corpus(df[df["party_simplified"] == "DEMOCRAT"].reset_index(drop=True))
dvr = corpus.create_dvr(equally_weighted=True)
sigs = corpus.create_signatures(epsilon=1/(len(dvr) * 2))

# %%
sigs
# Out:
# ([WEST VIRGINIA           0.004230
#   ARKANSAS                0.002622
#   INDIANA                 0.002463
#   OKLAHOMA                0.002408
#   PENNSYLVANIA            0.001775
#   OHIO                    0.001208
#   NEW YORK                0.001047
#   KANSAS                  0.001045
#   ALABAMA                 0.000947
#   ILLINOIS                0.000888
#   MISSOURI                0.000885
#   NORTH DAKOTA            0.000834
#   KENTUCKY                0.000821
#   MASSACHUSETTS           0.000778
#   TENNESSEE               0.000741
#   IOWA                    0.000676
#   SOUTH DAKOTA            0.000520
#   MINNESOTA               0.000357
#   RHODE ISLAND            0.000264
#   NEW JERSEY              0.000233
#   LOUISIANA               0.000232
#   NEBRASKA                0.000213
#   MISSISSIPPI             0.000159
#   WISCONSIN               0.000127
#   CONNECTICUT             0.000116
#   WYOMING                 0.000084
#   MICHIGAN                0.000071
#   MONTANA                 0.000069
#   MARYLAND                0.000026
#   CALIFORNIA              0.000000
#   VERMONT                 0.000000
#   UTAH                    0.000000
#   TEXAS                   0.000000
#   VIRGINIA                0.000000
#   WASHINGTON              0.000000
#   ARIZONA                 0.000000
#   SOUTH CAROLINA          0.000000
#   HAWAII                  0.000000
#   OREGON                  0.000000
#   COLORADO                0.000000
#   NORTH CAROLINA          0.000000
#   DELAWARE                0.000000
#   IDAHO                   0.000000
#   NEW HAMPSHIRE           0.000000
#   NEVADA                  0.000000
#   ALASKA                  0.000000
#   MAINE                   0.000000
#   DISTRICT OF COLUMBIA    0.000000
#   FLORIDA                 0.000000
#   GEORGIA                 0.000000
#   NEW MEXICO              0.000000
#   Name: 1976, dtype: float64,
#   WEST VIRGINIA           0.003698
#   KENTUCKY                0.002506
#   LOUISIANA               0.002345
#   ALABAMA                 0.002192
#   MISSISSIPPI             0.001964
#   MISSOURI                0.001815
#   TENNESSEE               0.001751
#   INDIANA                 0.001661
#   ARKANSAS                0.001572
#   MICHIGAN                0.001421
#   OHIO                    0.001201
#   OKLAHOMA                0.000894
#   ILLINOIS                0.000892
#   PENNSYLVANIA            0.000826
#   WISCONSIN               0.000712
#   MINNESOTA               0.000537
#   MARYLAND                0.000421
#   NEW YORK                0.000405
#   IOWA                    0.000291
#   RHODE ISLAND            0.000261
#   KANSAS                  0.000241
#   SOUTH DAKOTA            0.000069
#   WYOMING                 0.000024
#   CONNECTICUT             0.000020
#   NORTH DAKOTA            0.000011
#   MAINE                   0.000011
#   SOUTH CAROLINA          0.000006
#   GEORGIA                 0.000003
#   MONTANA                 0.000002
#   MASSACHUSETTS           0.000000
#   HAWAII                  0.000000
#   DISTRICT OF COLUMBIA    0.000000
#   ARIZONA                 0.000000
#   WASHINGTON              0.000000
#   VIRGINIA                0.000000
#   VERMONT                 0.000000
#   UTAH                    0.000000
#   TEXAS                   0.000000
#   FLORIDA                 0.000000
#   OREGON                  0.000000
#   IDAHO                   0.000000
#   ALASKA                  0.000000
#   COLORADO                0.000000
#   CALIFORNIA              0.000000
#   NORTH CAROLINA          0.000000
#   NEW MEXICO              0.000000
#   NEW JERSEY              0.000000
#   NEW HAMPSHIRE           0.000000
#   DELAWARE                0.000000
#   NEBRASKA                0.000000
#   NEVADA                  0.000000
#   Name: 1980, dtype: float64,
#   PENNSYLVANIA            0.002846
#   WEST VIRGINIA           0.001687
#   IOWA                    0.001221
#   NEW YORK                0.001158
#   OHIO                    0.000970
#   INDIANA                 0.000918
#   ILLINOIS                0.000853
#   MINNESOTA               0.000832
#   LOUISIANA               0.000666
#   MARYLAND                0.000641
#   KENTUCKY                0.000460
#   WISCONSIN               0.000355
#   OKLAHOMA                0.000316
#   DISTRICT OF COLUMBIA    0.000311
#   NORTH DAKOTA            0.000280
#   ALABAMA                 0.000275
#   TENNESSEE               0.000259
#   MISSOURI                0.000226
#   MASSACHUSETTS           0.000214
#   ARKANSAS                0.000185
#   MONTANA                 0.000173
#   MISSISSIPPI             0.000168
#   SOUTH DAKOTA            0.000147
#   KANSAS                  0.000139
#   RHODE ISLAND            0.000117
#   WYOMING                 0.000035
#   CONNECTICUT             0.000015
#   NEW JERSEY              0.000012
#   MICHIGAN                0.000011
#   NEBRASKA                0.000008
#   ALASKA                  0.000000
#   SOUTH CAROLINA          0.000000
#   ARIZONA                 0.000000
#   IDAHO                   0.000000
#   WASHINGTON              0.000000
#   VIRGINIA                0.000000
#   VERMONT                 0.000000
#   UTAH                    0.000000
#   TEXAS                   0.000000
#   CALIFORNIA              0.000000
#   COLORADO                0.000000
#   HAWAII                  0.000000
#   OREGON                  0.000000
#   DELAWARE                0.000000
#   MAINE                   0.000000
#   NORTH CAROLINA          0.000000
#   GEORGIA                 0.000000
#   NEW MEXICO              0.000000
#   NEW HAMPSHIRE           0.000000
#   NEVADA                  0.000000
#   FLORIDA                 0.000000
#   Name: 1984, dtype: float64,
#   IOWA                    1.157549e-03
#   WEST VIRGINIA           1.113674e-03
#   OKLAHOMA                1.075046e-03
#   KANSAS                  7.295515e-04
#   MISSOURI                6.577352e-04
#   NEW YORK                6.273943e-04
#   LOUISIANA               5.746387e-04
#   NORTH DAKOTA            5.213780e-04
#   NEBRASKA                4.866677e-04
#   WISCONSIN               4.807467e-04
#   MINNESOTA               4.402246e-04
#   SOUTH DAKOTA            4.106243e-04
#   OHIO                    3.523985e-04
#   PENNSYLVANIA            3.387526e-04
#   MASSACHUSETTS           3.194341e-04
#   KENTUCKY                2.706616e-04
#   ILLINOIS                2.506898e-04
#   MONTANA                 2.450847e-04
#   INDIANA                 2.321855e-04
#   MARYLAND                2.235576e-04
#   CONNECTICUT             1.832479e-04
#   RHODE ISLAND            1.696009e-04
#   TEXAS                   1.597810e-04
#   WYOMING                 1.339648e-04
#   IDAHO                   4.299880e-05
#   HAWAII                  3.859499e-05
#   UTAH                    2.611836e-05
#   ARKANSAS                2.458903e-05
#   MISSISSIPPI             1.925634e-05
#   ALASKA                  7.736440e-07
#   ALABAMA                 4.552807e-07
#   NEW MEXICO              0.000000e+00
#   NEW JERSEY              0.000000e+00
#   ARIZONA                 0.000000e+00
#   MICHIGAN                0.000000e+00
#   WASHINGTON              0.000000e+00
#   VIRGINIA                0.000000e+00
#   VERMONT                 0.000000e+00
#   MAINE                   0.000000e+00
#   CALIFORNIA              0.000000e+00
#   TENNESSEE               0.000000e+00
#   COLORADO                0.000000e+00
#   SOUTH CAROLINA          0.000000e+00
#   DELAWARE                0.000000e+00
#   DISTRICT OF COLUMBIA    0.000000e+00
#   NEVADA                  0.000000e+00
#   FLORIDA                 0.000000e+00
#   GEORGIA                 0.000000e+00
#   NEW HAMPSHIRE           0.000000e+00
#   NORTH CAROLINA          0.000000e+00
#   OREGON                  0.000000e+00
#   Name: 1988, dtype: float64,
#   ARKANSAS                1.624580e-03
#   MARYLAND                1.121945e-03
#   LOUISIANA               1.085120e-03
#   TENNESSEE               9.922716e-04
#   KENTUCKY                6.568585e-04
#   ILLINOIS                5.749717e-04
#   ALABAMA                 5.257849e-04
#   WEST VIRGINIA           5.065731e-04
#   MISSOURI                4.675918e-04
#   OKLAHOMA                4.354868e-04
#   NEW YORK                1.031148e-04
#   KANSAS                  8.684975e-05
#   WYOMING                 7.847174e-05
#   MICHIGAN                7.186175e-05
#   DISTRICT OF COLUMBIA    6.912610e-05
#   MISSISSIPPI             4.813760e-05
#   OHIO                    3.737352e-05
#   SOUTH DAKOTA            2.599492e-05
#   PENNSYLVANIA            1.676074e-05
#   IOWA                    1.672727e-05
#   CONNECTICUT             1.506339e-05
#   MONTANA                 1.416572e-05
#   NORTH DAKOTA            7.955753e-06
#   VERMONT                 7.011727e-06
#   RHODE ISLAND            4.847718e-06
#   ALASKA                  1.076803e-06
#   INDIANA                 3.238061e-07
#   TEXAS                   0.000000e+00
#   CALIFORNIA              0.000000e+00
#   ARIZONA                 0.000000e+00
#   ALABAMA                 0.000029
#   NEW HAMPSHIRE           0.000027
#   RHODE ISLAND            0.000024
#   DELAWARE                0.000019
#   ILLINOIS                0.000019
#   MAINE                   0.000018
#   ARKANSAS                0.000018
#   WISCONSIN               0.000008
#   KENTUCKY                0.000006
#   VERMONT                 0.000003
#   SOUTH CAROLINA          0.000000
#   CALIFORNIA              0.000000
#   OREGON                  0.000000
#   PENNSYLVANIA            0.000000
#   TEXAS                   0.000000
#   SOUTH DAKOTA            0.000000
#   NORTH DAKOTA            0.000000
#   UTAH                    0.000000
#   VIRGINIA                0.000000
#   WASHINGTON              0.000000
#   WEST VIRGINIA           0.000000
#   OHIO                    0.000000
#   COLORADO                0.000000
#   NORTH CAROLINA          0.000000
#   INDIANA                 0.000000
#   NEW MEXICO              0.000000
#   NEVADA                  0.000000
#   NEBRASKA                0.000000
#   MONTANA                 0.000000
#   ALASKA                  0.000000
#   MISSISSIPPI             0.000000
#   MINNESOTA               0.000000
#   DISTRICT OF COLUMBIA    0.000000
#   GEORGIA                 0.000000
#   HAWAII                  0.000000
#   IDAHO                   0.000000
#   KANSAS                  0.000000
#   IOWA                    0.000000
#   WYOMING                 0.000000
#   Name: 2000, dtype: float64,
#   ARIZONA                 1.052982e-03
#   FLORIDA                 9.398427e-04
#   OHIO                    6.258049e-04
#   MICHIGAN                2.686996e-04
#   NEW HAMPSHIRE           2.596061e-04
#   OREGON                  2.396910e-04
#   NEVADA                  2.152665e-04
#   WISCONSIN               1.836764e-04
#   MAINE                   1.728379e-04
#   WASHINGTON              1.613613e-04
#   PENNSYLVANIA            1.022737e-04
#   MINNESOTA               9.682193e-05
#   MISSOURI                7.590302e-05
#   NEW MEXICO              5.546160e-05
#   VERMONT                 5.471441e-05
#   TENNESSEE               5.322428e-05
#   ALASKA                  3.819918e-05
#   COLORADO                2.578213e-05
#   DELAWARE                9.138633e-06
#   MASSACHUSETTS           8.013093e-06
#   ARKANSAS                4.942896e-06
#   IOWA                    4.687713e-06
#   NEW YORK                1.929851e-06
#   CONNECTICUT             6.551597e-07
#   CALIFORNIA              5.428100e-07
#   SOUTH DAKOTA            4.431559e-07
#   ILLINOIS                3.550176e-07
#   KENTUCKY                1.749369e-07
#   NEW JERSEY              1.084991e-07
#   RHODE ISLAND            0.000000e+00
#   SOUTH CAROLINA          0.000000e+00
#   WEST VIRGINIA           0.000000e+00
#   VIRGINIA                0.000000e+00
#   OKLAHOMA                0.000000e+00
#   UTAH                    0.000000e+00
#   TEXAS                   0.000000e+00
#   ALABAMA                 0.000000e+00
#   NORTH DAKOTA            0.000000e+00
#   NORTH CAROLINA          0.000000e+00
#   NEBRASKA                0.000000e+00
#   MONTANA                 0.000000e+00
#   MISSISSIPPI             0.000000e+00
#   MARYLAND                0.000000e+00
#   LOUISIANA               0.000000e+00
#   KANSAS                  0.000000e+00
#   INDIANA                 0.000000e+00
#   IDAHO                   0.000000e+00
#   HAWAII                  0.000000e+00
#   GEORGIA                 0.000000e+00
#   DISTRICT OF COLUMBIA    0.000000e+00
#   TENNESSEE               0.000000e+00
#   NORTH DAKOTA            0.000000e+00
#   UTAH                    0.000000e+00
#   WEST VIRGINIA           0.000000e+00
#   TEXAS                   0.000000e+00
#   MISSOURI                0.000000e+00
#   NEW YORK                0.000000e+00
#   NEW JERSEY              0.000000e+00
#   NEBRASKA                0.000000e+00
#   MONTANA                 0.000000e+00
#   MINNESOTA               0.000000e+00
#   MICHIGAN                0.000000e+00
#   MASSACHUSETTS           0.000000e+00
#   LOUISIANA               0.000000e+00
#   KENTUCKY                0.000000e+00
#   KANSAS                  0.000000e+00
#   IOWA                    0.000000e+00
#   INDIANA                 0.000000e+00
#   ILLINOIS                0.000000e+00
#   CONNECTICUT             0.000000e+00
#   ARKANSAS                0.000000e+00
#   WYOMING                 0.000000e+00
#   Name: 2012, dtype: float64,
#   CALIFORNIA              0.005626
#   FLORIDA                 0.005552
#   NORTH CAROLINA          0.002225
#   VIRGINIA                0.001693
#   TEXAS                   0.001515
#   COLORADO                0.001509
#   NEVADA                  0.001422
#   GEORGIA                 0.001319
#   WASHINGTON              0.000559
#   SOUTH CAROLINA          0.000350
#   DISTRICT OF COLUMBIA    0.000146
#   OREGON                  0.000129
#   NEW HAMPSHIRE           0.000105
#   DELAWARE                0.000072
#   NEW JERSEY              0.000045
#   MASSACHUSETTS           0.000032
#   UTAH                    0.000022
#   ALASKA                  0.000017
#   NEW MEXICO              0.000007
#   NEW YORK                0.000000
#   NORTH DAKOTA            0.000000
#   OHIO                    0.000000
#   ALABAMA                 0.000000
#   OKLAHOMA                0.000000
#   PENNSYLVANIA            0.000000
#   RHODE ISLAND            0.000000
#   SOUTH DAKOTA            0.000000
#   VERMONT                 0.000000
#   WEST VIRGINIA           0.000000
#   WISCONSIN               0.000000
#   TENNESSEE               0.000000
#   MISSOURI                0.000000
#   NEBRASKA                0.000000
#   IOWA                    0.000000
#   ARIZONA                 0.000000
#   ARKANSAS                0.000000
#   CONNECTICUT             0.000000
#   HAWAII                  0.000000
#   IDAHO                   0.000000
#   ILLINOIS                0.000000
#   INDIANA                 0.000000
#   KANSAS                  0.000000
#   MONTANA                 0.000000
#   KENTUCKY                0.000000
#   LOUISIANA               0.000000
#   MAINE                   0.000000
#   MARYLAND                0.000000
#   MICHIGAN                0.000000
#   MINNESOTA               0.000000
#   MISSISSIPPI             0.000000
#   WYOMING                 0.000000
#   Name: 2016, dtype: float64,
#   ARIZONA                 0.006072
#   CALIFORNIA              0.004436
#   TEXAS                   0.002837
#   MARYLAND                0.002740
#   COLORADO                0.002130
#   FLORIDA                 0.001986
#   GEORGIA                 0.001611
#   NEVADA                  0.001496
#   NORTH CAROLINA          0.001250
#   UTAH                    0.001244
#   WASHINGTON              0.001142
#   VIRGINIA                0.000815
#   SOUTH CAROLINA          0.000284
#   OREGON                  0.000272
#   IDAHO                   0.000043
#   DELAWARE                0.000041
#   ALASKA                  0.000027
#   NEW HAMPSHIRE           0.000025
#   HAWAII                  0.000019
#   NEW MEXICO              0.000011
#   VERMONT                 0.000008
#   DISTRICT OF COLUMBIA    0.000001
#   SOUTH DAKOTA            0.000000
#   TENNESSEE               0.000000
#   RHODE ISLAND            0.000000
#   PENNSYLVANIA            0.000000
#   OKLAHOMA                0.000000
#   OHIO                    0.000000
#   WEST VIRGINIA           0.000000
#   WISCONSIN               0.000000
#   NORTH DAKOTA            0.000000
#   ALABAMA                 0.000000
#   MISSOURI                0.000000
#   NEW YORK                0.000000
#   NEW JERSEY              0.000000
#   ARKANSAS                0.000000
#   CONNECTICUT             0.000000
#   ILLINOIS                0.000000
#   INDIANA                 0.000000
#   IOWA                    0.000000
#   KANSAS                  0.000000
#   KENTUCKY                0.000000
#   LOUISIANA               0.000000
#   MAINE                   0.000000
#   MASSACHUSETTS           0.000000
#   MICHIGAN                0.000000
#   MINNESOTA               0.000000
#   MISSISSIPPI             0.000000
#   MONTANA                 0.000000
#   NEBRASKA                0.000000
#   WYOMING                 0.000000
#   Name: 2020, dtype: float64],
#  [MARYLAND          0.000026
#   ARIZONA           0.000000
#   FLORIDA           0.000000
#   CALIFORNIA        0.000000
#   NEVADA            0.000000
#   WEST VIRGINIA     0.004230
#   COLORADO          0.000000
#   NORTH CAROLINA    0.000000
#   LOUISIANA         0.000232
#   GEORGIA           0.000000
#   VIRGINIA          0.000000
#   ARKANSAS          0.002622
#   OHIO              0.001208
#   WASHINGTON        0.000000
#   OKLAHOMA          0.002408
#   PENNSYLVANIA      0.001775
#   MISSOURI          0.000885
#   TEXAS             0.000000
#   INDIANA           0.002463
#   KENTUCKY          0.000821
#   TENNESSEE         0.000741
#   NEW YORK          0.001047
#   ILLINOIS          0.000888
#   ALABAMA           0.000947
#   IOWA              0.000676
#   MICHIGAN          0.000071
#   NEW HAMPSHIRE     0.000000
#   SOUTH CAROLINA    0.000000
#   WISCONSIN         0.000127
#   MINNESOTA         0.000357
#   Name: 1976, dtype: float64,
#   MARYLAND          0.000421
#   ARIZONA           0.000000
#   FLORIDA           0.000000
#   CALIFORNIA        0.000000
#   NEVADA            0.000000
#   WEST VIRGINIA     0.003698
#   COLORADO          0.000000
#   NORTH CAROLINA    0.000000
#   LOUISIANA         0.002345
#   GEORGIA           0.000003
#   VIRGINIA          0.000000
#   ARKANSAS          0.001572
#   OHIO              0.001201
#   WASHINGTON        0.000000
#   OKLAHOMA          0.000894
#   PENNSYLVANIA      0.000826
#   MISSOURI          0.001815
#   TEXAS             0.000000
#   INDIANA           0.001661
#   KENTUCKY          0.002506
#   TENNESSEE         0.001751
#   NEW YORK          0.000405
#   ILLINOIS          0.000892
#   ALABAMA           0.002192
#   IOWA              0.000291
#   MICHIGAN          0.001421
#   NEW HAMPSHIRE     0.000000
#   SOUTH CAROLINA    0.000006
#   WISCONSIN         0.000712
#   MINNESOTA         0.000537
#   Name: 1980, dtype: float64,
#   MARYLAND          0.000641
#   ARIZONA           0.000000
#   FLORIDA           0.000000
#   CALIFORNIA        0.000000
#   NEVADA            0.000000
#   WEST VIRGINIA     0.001687
#   COLORADO          0.000000
#   NEVADA            0.000000
#   WEST VIRGINIA     0.000260
#   COLORADO          0.000000
#   NORTH CAROLINA    0.000000
#   LOUISIANA         0.002064
#   GEORGIA           0.000000
#   VIRGINIA          0.000000
#   ARKANSAS          0.000674
#   OHIO              0.000163
#   WASHINGTON        0.000000
#   OKLAHOMA          0.000332
#   PENNSYLVANIA      0.000000
#   MISSOURI          0.000052
#   TEXAS             0.000000
#   INDIANA           0.000000
#   KENTUCKY          0.000140
#   TENNESSEE         0.000324
#   NEW YORK          0.000453
#   ILLINOIS          0.000000
#   ALABAMA           0.000085
#   IOWA              0.000021
#   MICHIGAN          0.000111
#   NEW HAMPSHIRE     0.000022
#   SOUTH CAROLINA    0.000000
#   WISCONSIN         0.000000
#   MINNESOTA         0.000000
#   Name: 1996, dtype: float64,
#   MARYLAND          0.001389
#   ARIZONA           0.000146
#   FLORIDA           0.000039
#   CALIFORNIA        0.000000
#   NEVADA            0.000000
#   WEST VIRGINIA     0.000000
#   COLORADO          0.000000
#   NORTH CAROLINA    0.000000
#   LOUISIANA         0.000078
#   GEORGIA           0.000000
#   VIRGINIA          0.000000
#   ARKANSAS          0.000018
#   OHIO              0.000000
#   WASHINGTON        0.000000
#   OKLAHOMA          0.000039
#   PENNSYLVANIA      0.000000
#   MISSOURI          0.000074
#   TEXAS             0.000000
#   INDIANA           0.000000
#   KENTUCKY          0.000006
#   TENNESSEE         0.000353
#   NEW YORK          0.000528
#   ILLINOIS          0.000019
#   ALABAMA           0.000029
#   IOWA              0.000000
#   MICHIGAN          0.000203
#   NEW HAMPSHIRE     0.000027
#   SOUTH CAROLINA    0.000000
#   WISCONSIN         0.000008
#   MINNESOTA         0.000000
#   Name: 2000, dtype: float64,
#   MARYLAND          0.000000e+00
#   ARIZONA           1.052982e-03
#   FLORIDA           9.398427e-04
#   CALIFORNIA        5.428100e-07
#   NEVADA            2.152665e-04
#   WEST VIRGINIA     0.000000e+00
#   COLORADO          2.578213e-05
#   NORTH CAROLINA    0.000000e+00
#   LOUISIANA         0.000000e+00
#   GEORGIA           0.000000e+00
#   VIRGINIA          0.000000e+00
#   ARKANSAS          4.942896e-06
#   OHIO              6.258049e-04
#   WASHINGTON        1.613613e-04
#   OKLAHOMA          0.000000e+00
#   PENNSYLVANIA      1.022737e-04
#   MISSOURI          7.590302e-05
#   TEXAS             0.000000e+00
#   INDIANA           0.000000e+00
#   KENTUCKY          1.749369e-07
#   TENNESSEE         5.322428e-05
#   NEW YORK          1.929851e-06
#   ILLINOIS          3.550176e-07
#   ALABAMA           0.000000e+00
#   IOWA              4.687713e-06
#   MICHIGAN          2.686996e-04
#   NEW HAMPSHIRE     2.596061e-04
#   SOUTH CAROLINA    0.000000e+00
#   WISCONSIN         1.836764e-04
#   MINNESOTA         9.682193e-05
#   Name: 2004, dtype: float64,
#   MARYLAND          2.038548e-03
#   ARIZONA           7.071458e-04
#   FLORIDA           7.972795e-04
#   CALIFORNIA        6.762715e-05
#   NEVADA            6.706541e-04
#   WEST VIRGINIA     0.000000e+00
#   COLORADO          2.449572e-04
#   NORTH CAROLINA    4.427779e-04
#   LOUISIANA         0.000000e+00
#   GEORGIA           1.632340e-04
#   VIRGINIA          3.380724e-04
#   ARKANSAS          0.000000e+00
#   OHIO              0.000000e+00
#   WASHINGTON        2.828219e-05
#   OKLAHOMA          0.000000e+00
#   PENNSYLVANIA      0.000000e+00
#   MISSOURI          0.000000e+00
#   TEXAS             0.000000e+00
#   INDIANA           6.985404e-05
#   KENTUCKY          0.000000e+00
#   TENNESSEE         0.000000e+00
#   NEW YORK          0.000000e+00
#   ILLINOIS          0.000000e+00
#   ALABAMA           0.000000e+00
#   IOWA              0.000000e+00
#   MICHIGAN          4.609600e-05
#   NEW HAMPSHIRE     1.061787e-04
#   SOUTH CAROLINA    4.040737e-05
#   WISCONSIN         5.326604e-07
#   MINNESOTA         0.000000e+00
#   Name: 2008, dtype: float64,
#   MARYLAND          0.003682
#   ARIZONA           0.001097
#   FLORIDA           0.001691
#   CALIFORNIA        0.000075
#   NEVADA            0.000967
#   WEST VIRGINIA     0.000000
#   COLORADO          0.000838
#   NORTH CAROLINA    0.001297
#   LOUISIANA         0.000000
#   GEORGIA           0.000243
#   VIRGINIA          0.000934
#   ARKANSAS          0.000000
#   OHIO              0.000000
#   WASHINGTON        0.000259
#   OKLAHOMA          0.000000
#   PENNSYLVANIA      0.000000
#   MISSOURI          0.000000
#   TEXAS             0.000000
#   INDIANA           0.000000
#   KENTUCKY          0.000000
#   TENNESSEE         0.000000
#   NEW YORK          0.000000
#   ILLINOIS          0.000000
#   ALABAMA           0.000000
#   IOWA              0.000000
#   MICHIGAN          0.000000
#   NEW HAMPSHIRE     0.000131
#   SOUTH CAROLINA    0.000200
#   WISCONSIN         0.000018
#   MINNESOTA         0.000000
#   Name: 2012, dtype: float64,
#   MARYLAND          0.000000
#   ARIZONA           0.000000
#   FLORIDA           0.005552
#   CALIFORNIA        0.005626
#   NEVADA            0.001422
#   WEST VIRGINIA     0.000000
#   COLORADO          0.001509
#   NORTH CAROLINA    0.002225
#   LOUISIANA         0.000000
#   GEORGIA           0.001319
#   VIRGINIA          0.001693
#   ARKANSAS          0.000000
#   OHIO              0.000000
#   WASHINGTON        0.000559
#   OKLAHOMA          0.000000
#   PENNSYLVANIA      0.000000
#   MISSOURI          0.000000
#   TEXAS             0.001515
#   INDIANA           0.000000
#   KENTUCKY          0.000000
#   TENNESSEE         0.000000
#   NEW YORK          0.000000
#   ILLINOIS          0.000000
#   ALABAMA           0.000000
#   IOWA              0.000000
#   MICHIGAN          0.000000
#   NEW HAMPSHIRE     0.000105
#   SOUTH CAROLINA    0.000350
#   WISCONSIN         0.000000
#   MINNESOTA         0.000000
#   Name: 2016, dtype: float64,
#   MARYLAND          0.002740
#   ARIZONA           0.006072
#   FLORIDA           0.001986
#   CALIFORNIA        0.004436
#   NEVADA            0.001496
#   WEST VIRGINIA     0.000000
#   COLORADO          0.002130
#   NORTH CAROLINA    0.001250
#   LOUISIANA         0.000000
#   GEORGIA           0.001611
#   VIRGINIA          0.000815
#   ARKANSAS          0.000000
#   OHIO              0.000000
#   WASHINGTON        0.001142
#   OKLAHOMA          0.000000
#   PENNSYLVANIA      0.000000
#   MISSOURI          0.000000
#   TEXAS             0.002837
#   INDIANA           0.000000
#   KENTUCKY          0.000000
#   TENNESSEE         0.000000
#   NEW YORK          0.000000
#   ILLINOIS          0.000000
#   ALABAMA           0.000000
#   IOWA              0.000000
#   MICHIGAN          0.000000
#   NEW HAMPSHIRE     0.000025
#   SOUTH CAROLINA    0.000284
#   WISCONSIN         0.000000
#   MINNESOTA         0.000000
#   Name: 2020, dtype: float64],
#  array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True]))

# %%
df[(df["document"]==1976) & (df["element"]=="CALIFORNIA")]
# Out:
#    document  frequency_in_document party_simplified     element
# 8      1976                3882244       REPUBLICAN  CALIFORNIA
# 9      1976                3742284         DEMOCRAT  CALIFORNIA

# %%
for i, s in enumerate(sigs[0]):
    s.to_csv(f"results/us_elections/signatures/{1976 + i * 4}.csv")
dvr.to_csv("results/us_elections/dvr.csv", index=False)
# sigs[0][8].to_csv("2008.csv")

# %%
sigs[0][0].loc["CALIFORNIA"]
# Out:
# 0.0

# %%
num_to_year = {
    14: 1996,
    15: 1999,
    16: 2003,
    17: 2006,
    18: 2009,
    19: 2013,
    20: 2015,
    21: 2018,
    22: 2019,
    23: 2020,
    24: 2021,
    25: 2022
}

# %% [markdown]
# ### Preprocessing

# %%
# heb_cols = ["שם ישוב", "סמל ישוב", "בזב", "מצביעים", "פסולים", "כשרים"]
# eng_cols = ["town_name", "town_code", "bzb", "voters", "valid_votes", "invalid_votes"]
# years = ("2015", "2019a", "2019b", "2020", "2021") #  ("2015 - hebrew", "2019 - hebrew",
# drop_cols = {
#     "2019b": ["סמל ועדה"],
#     "2020": ["סמל ועדה", "Unnamed: 37"],
#     "2021": ["סמל ועדה", "Unnamed: 46"],
# } | {y: [] for y in years[:-3]}
full_df = []
# kv_df = []
for num, year in num_to_year.items():
    if num <= 20:
        df = pd.read_excel(f"data/elections/results_{num}.xls")
    else:
        enc = {"encoding":"iso8859_8"} if num != 25 else {}
        df = pd.read_csv(f"data/elections/results_{num}.csv", **enc)
    print(year)
    df.loc[
        ((df["שם ישוב"] == "מעטפות חיצוניות") | (df["שם ישוב"] == "מעטפות כפולות")),
        "סמל ישוב",
    ] = 99999
    df = df.drop(
        columns=set(df.columns.tolist())
        & {
            "קלפי",
            "פיצול",
            "שם ישוב",
            "כתובת",
            "בעלי זכות בחירה",
            "בזב",
            "נפה",
            "מצביעים",
            "כשרים",
            "פסולים",
            "מספר קלפי",
            "ברזל",
            "סמל ועדה",
            "שופט",
            "ריכוז",
            "סמל קלפי",
        }
    )
    df = df.rename(columns={"סמל ישוב": "element"})
    full_df.append(
        df.groupby("element", as_index=False)
        .sum()
        .melt(id_vars=["element"], value_name="frequency_in_document")
        .assign(document=year)
    )
#     kv_df.append(df[["town_code", "town_name"]])
#     emet_df.append(df[df["party"] == "אמת"][["document","town_code", "votes"]].rename(columns={"town_code": "element", "votes": "frequency_in_document"}).reset_index(drop=True))

full_df = pd.concat(full_df)
full_df = full_df[full_df["frequency_in_document"]>0].reset_index(drop=True).replace({"אמת ": "אמת"})
for variable in full_df["variable"].drop_duplicates().to_list():
    full_df[full_df["variable"] == variable].drop(columns=["variable"]).to_csv(f"data/elections/parties/{variable}.csv", index=False)
# emet_df["element"] = emet_df["element"].replace(9999, 99999)
# emet_df
full_df = full_df.rename(columns={"element": "city", "variable": "element"})
# Out:
# 1996
# 1999
# 2003
# 2006
# 2009
# 2013
# 2015
# 2018
# 2019
# 2020
# 2021
# 2022

# %%
cs = []
for i in [3000, 3000]:
    cs.append(full_df[full_df['city'] == i].reset_index(drop=True).drop(columns=["city"]))

# %%
k = ["שם יישוב", "סמל יישוב"]
v = ["name", "element"]
kv = pd.read_excel("data/elections/bycode2021.xlsx")[k].rename(columns=dict(zip(k, v)))
kv = pd.concat([kv, pd.DataFrame(["מעטפות חיצוניות", 99999], index=v).T], ignore_index=True)

# pd.DataFrame.from_dict(dict(zip(v, )), orient="columns")

# %%
css = []
for f in cs:
    corpus = Corpus(f)
    dvr = corpus.create_dvr()
    corpus.create_signatures(epsilon=1/(len(dvr) * 2))
    css.append(corpus)

# print(css)
spd = sockpuppet_distance(*css)
sockpuppet_matrix(spd, "Tel Aviv", "Tel Aviv 2")
# Out:
# /home/alexzabbey/.virtualenvs/lpa/lib/python3.10/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.Chart(...)

# %% [markdown]
# ### LPA

# %%
corpus = Corpus(freq=emet_df)
dvr = corpus.create_dvr()
pd.merge(dvr, kv).head(20)
# Out:
#    element  global_weight             name
# 0     3000       0.105517          ירושלים
# 1     6100       0.053490          בני ברק
# 2    99999       0.047087  מעטפות חיצוניות
# 3       70       0.045611            אשדוד
# 4     5000       0.043848     תל אביב -יפו
# 5     7400       0.032748            נתניה
# 6     6600       0.030517            חולון
# 7     9000       0.029700          באר שבע
# 8     7900       0.028214        פתח תקווה
# 9     8300       0.021468      ראשון לציון
# 10    6200       0.020434            בת ים
# 11    7100       0.020389           אשקלון
# 12    1309       0.016647             אלעד
# 13    2610       0.016163          בית שמש
# 14    4000       0.015572             חיפה
# 15    8400       0.014965           רחובות
# 16     246       0.014388           נתיבות
# 17    8500       0.013670             רמלה
# 18    8600       0.012051           רמת גן
# 19    2630       0.011772         קריית גת

# %%
epsilon_frac = 2
epsilon = 1 / (len(dvr) * epsilon_frac)
epsilon
# Out:
# 0.00039184952978056425

# %%
prevelent = floor(len(corpus) * 0.75)
print(prevelent)
signatures, most_significant, temporary_array = corpus.create_signatures(
    epsilon=epsilon, most_significant=30, sig_length=500, prevelent=prevelent
)
display(signatures[0].head(10))
# Out:
# 9
# 99999   -0.322609
# 1309    -0.087919
# 294      0.071905
# 6600    -0.071485
# 289      0.070993
# 633      0.061211
# 5000    -0.058087
# 139      0.055845
# 167      0.052052
# 7400    -0.051288
# Name: 1996, dtype: float64
